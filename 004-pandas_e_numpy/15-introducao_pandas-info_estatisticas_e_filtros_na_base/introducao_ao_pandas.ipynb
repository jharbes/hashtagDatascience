# %% [markdown]
# # Pandas
#
# - Alta performance e fácil uso para trabalhar com dados
# - Tem muitas coisas que lembram o Excel
# - O DataFrame é usado em várias outras bibliotecas de Ciência de Dados
# - https://pandas.pydata.org/
# <br><br>
# - O Pandas vai <font color="blue">**desde a importação da base, passando por toda a análise exploratória até a exibição de gráficos** </font>

# %%
# Importando o pandas
import pandas as pd

# %% [markdown]
# ### Conseguimos importar praticamente todas as bases de dados usando o pandas

# %% [markdown]
# **Importar uma base em csv:** <br>
# <font color="blue">**pd.read_csv(**</font>"arquivo_excel.xlsx"<font color="blue">**)**</font>

# %%
base = pd.read_csv("07_pandas.csv")

# %% [markdown]
# ### E também visualizar todas as informações sobre essa base

# %% [markdown]
# **As 5 primeiras linhas:** <br>
# base<font color="blue">**.head()**</font>

# %%
# Visualizando as 5 primeiras linhas
display(base.head())

# Visualizando as 15 primeiras linhas
display(base.head(15))
# Out:
#         As of  Rank Year to Date Rank Last Week Rank
# 0  2020-04-01     1                 1              1  \
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes  \
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# 3         Mar 26, 2020               5                30
# 4         Mar 20, 2020               9                55
#          As of  Rank Year to Date Rank Last Week Rank
# 0   2020-04-01     1                 1              1  \
# 1   2020-04-01     2                 2              -
# 2   2020-04-01     3                 3              2
# 3   2020-04-01     4                 4              -
# 4   2020-04-01     5                 5              4
# 5   2020-04-01     6                 6              -
# 6   2020-04-01     7                10              -
# 7   2020-04-01     8                 7              5
# 8   2020-04-01     9                 8              -
# 9   2020-04-01    10                 9              -
# 10  2020-04-02     1                 1              1
# 11  2020-04-02     2                 2              -
# 12  2020-04-02     3                 3              2
# 13  2020-04-02     4                 -              -
# 14  2020-04-02     5                 -              -
#
#                            Title     Type Netflix Exclusive
# 0   Tiger King: Murder, Mayhem …  TV Show               Yes  \
# 1                          Ozark  TV Show               Yes
# 2                   All American  TV Show               NaN
# 3                   Blood Father    Movie               NaN
# 4                   The Platform    Movie               Yes
# 5    Car Masters: Rust to Riches  TV Show               Yes
# 6                     Unorthodox  TV Show               Yes
# 7                  Love is Blind  TV Show               Yes
# 8                        Badland    Movie               NaN
# 9                       Uncorked    Movie               Yes
# 10  Tiger King: Murder, Mayhem …  TV Show               Yes
# 11                         Ozark  TV Show               Yes
# 12                  All American  TV Show               NaN
# 13                    Nailed It!  TV Show               Yes
# 14     How to Fix a Drug Scandal  TV Show               Yes
#
#    Netflix Release Date  Days In Top 10  Viewership Score
# 0          Mar 20, 2020               9                90
# 1          Jul 21, 2017               5                45
# 2          Mar 28, 2019               9                76
# 3          Mar 26, 2020               5                30
# 4          Mar 20, 2020               9                55
# 5          Sep 14, 2018               4                14
# 6          Mar 26, 2020               2                 5
# 7          Feb 13, 2020               9                40
# 8          Mar 26, 2020               4                11
# 9          Mar 27, 2020               4                15
# 10         Mar 20, 2020              10               100
# 11         Jul 21, 2017               6                54
# 12         Mar 28, 2019              10                84
# 13          Mar 9, 2018               1                 7
# 14          Apr 1, 2020               1                 6

# %% [markdown]
# **As 5 últimas linhas:** <br>
# base<font color="blue">**.tail()**</font>

# %%
# Visualizando as 5 últimas linhas
base.tail()
# Out:
#            As of  Rank Year to Date Rank Last Week Rank                Title
# 7095  2022-03-11     6                 5              1  Worst Roommate Ever  \
# 7096  2022-03-11     7                 7              2    Vikings: Valhalla
# 7097  2022-03-11     8                 8              -              Shooter
# 7098  2022-03-11     9                 9              7              Shrek 2
# 7099  2022-03-11    10                10              -                Shrek
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10
# 7095  TV Show               Yes          Mar 1, 2022              10  \
# 7096  TV Show               Yes         Feb 25, 2022              14
# 7097    Movie               NaN          Aug 1, 2014               3
# 7098    Movie               NaN          Mar 1, 2022              10
# 7099    Movie               NaN          May 1, 2018               7
#
#       Viewership Score
# 7095                81
# 7096               100
# 7097                 7
# 7098                33
# 7099                12

# %% [markdown]
# **O tamanho da base:** <br>
# base<font color="blue">**.shape**</font>

# %%
# Tamanho da base
base.shape
# Out:
# (7100, 10)

# %% [markdown]
# **Ou podemos usar o display para visualizar tudo isso de uma só vez:** <br>
# <font color="blue">**display(**</font>base<font color="blue">**)**</font>

# %%
# Visualizando primeiras e últimas linhas e tamanho da base
display(base)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank
# 0     2020-04-01     1                 1              1  \
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes  \
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# 3                     Blood Father    Movie               NaN
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie               NaN
# 7098                       Shrek 2    Movie               NaN
# 7099                         Shrek    Movie               NaN
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0            Mar 20, 2020               9                90
# 1            Jul 21, 2017               5                45
# 2            Mar 28, 2019               9                76
# 3            Mar 26, 2020               5                30
# 4            Mar 20, 2020               9                55
# ...                   ...             ...               ...
# 7095          Mar 1, 2022              10                81
# 7096         Feb 25, 2022              14               100
# 7097          Aug 1, 2014               3                 7
# 7098          Mar 1, 2022              10                33
# 7099          May 1, 2018               7                12
#
# [7100 rows x 10 columns]

# %% [markdown]
# ### DataFrame e Series

# %% [markdown]
# **Essa base que acabamos de importar é um DataFrame!**

# %%
type(base)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Também podemos criar um novo DataFrame usando um dicionário:**

# %%
# Criando o dicionários
dic = {
    "funcionarios": ['Lucas','Bia','Jean','Gabi','Pedro'],
    "venda_valor": [150000,230000,82000,143000,184000],
    "comissao": [5,8,8,5,12]
}

# %%
type(dic)
# Out:
# dict

# %%
dic
# Out:
# {'funcionarios': ['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'],
#  'venda_valor': [150000, 230000, 82000, 143000, 184000],
#  'comissao': [5, 8, 8, 5, 12]}

# %%
# Transformando esse dicionário em um DataFrame
base_dic = pd.DataFrame(dic)

print(base_dic)
# Out:
#   funcionarios  venda_valor  comissao
# 0        Lucas       150000         5
# 1          Bia       230000         8
# 2         Jean        82000         8
# 3         Gabi       143000         5
# 4        Pedro       184000        12

# %%
# Verificando o tipo do dado
type(base_dic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Cada coluna do DataFrame é uma Series, assim:** <br>
# <font color="blue">**series = DataFrame["coluna"]**</font>

# %%
series_funcionarios = base_dic["funcionarios"]

series_funcionarios
# Out:
# 0    Lucas
# 1      Bia
# 2     Jean
# 3     Gabi
# 4    Pedro
# Name: funcionarios, dtype: object

# %%
print(series_funcionarios.index)

print(series_funcionarios.values)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# ['Lucas' 'Bia' 'Jean' 'Gabi' 'Pedro']

# %%
print(type(series_funcionarios))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# **Para filtrar uma única coluna e continuar sendo um DataFrame, podemos fazer:** <br>
# <font color="blue">**series = DataFrame[["coluna"]]**</font>

# %%
dataframe_funcionarios = base_dic[["funcionarios"]]

print(dataframe_funcionarios)
# Out:
#   funcionarios
# 0        Lucas
# 1          Bia
# 2         Jean
# 3         Gabi
# 4        Pedro

# %%
type(dataframe_funcionarios)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Podemos aplicar vários conceitos que vimos no NumPy!

# %% [markdown]
# ### Assim como o NumPy, ele também mostra as informações gerais

# %%
# Mostrando somente o tipo dos dados
base.dtypes
# Out:
# As of                   object
# Rank                     int64
# Year to Date Rank       object
# Last Week Rank          object
# Title                   object
# Type                    object
# Netflix Exclusive       object
# Netflix Release Date    object
# Days In Top 10           int64
# Viewership Score         int64
# dtype: object

# %% [markdown]
# **Tipos de dados e valores vazios:** <br>
# base<font color="blue">**.info()**</font>

# %%
# Mostrando o tipo de dados e os valores vazios
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
# Contando os valores vazios por coluna
base.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
# Mostrando onde estão os valores vazios
display(base.isnull())
# Out:
#       As of   Rank  Year to Date Rank  Last Week Rank  Title   Type
# 0     False  False              False           False  False  False  \
# 1     False  False              False           False  False  False
# 2     False  False              False           False  False  False
# 3     False  False              False           False  False  False
# 4     False  False              False           False  False  False
# ...     ...    ...                ...             ...    ...    ...
# 7095  False  False              False           False  False  False
# 7096  False  False              False           False  False  False
# 7097  False  False              False           False  False  False
# 7098  False  False              False           False  False  False
# 7099  False  False              False           False  False  False
#
#       Netflix Exclusive  Netflix Release Date  Days In Top 10
# 0                 False                 False           False  \
# 1                 False                 False           False
# 2                  True                 False           False
# 3                  True                 False           False
# 4                 False                 False           False
# ...                 ...                   ...             ...
# 7095              False                 False           False
# 7096              False                 False           False
# 7097               True                 False           False
# 7098               True                 False           False
# 7099               True                 False           False
#
#       Viewership Score
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 7095             False
# 7096             False
# 7097             False
# 7098             False
# 7099             False
#
# [7100 rows x 10 columns]

# %%
base.head()
# Out:
#         As of  Rank Year to Date Rank Last Week Rank
# 0  2020-04-01     1                 1              1  \
# 1  2020-04-01     2                 2              -
# 2  2020-04-01     3                 3              2
# 3  2020-04-01     4                 4              -
# 4  2020-04-01     5                 5              4
#
#                           Title     Type Netflix Exclusive
# 0  Tiger King: Murder, Mayhem …  TV Show               Yes  \
# 1                         Ozark  TV Show               Yes
# 2                  All American  TV Show               NaN
# 3                  Blood Father    Movie               NaN
# 4                  The Platform    Movie               Yes
#
#   Netflix Release Date  Days In Top 10  Viewership Score
# 0         Mar 20, 2020               9                90
# 1         Jul 21, 2017               5                45
# 2         Mar 28, 2019               9                76
# 3         Mar 26, 2020               5                30
# 4         Mar 20, 2020               9                55

# %%
# True = 1, False = 0, usamos essa logica para contar o numero de valores nulos da tabela
print(False + False + False)
print(True + False + False)
print(True + True + False)
print(True + True + True)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ### <font color="blue">Obs: </font>Podemos limitar a base escolhendo apenas as colunas que queremos trabalhar
#
# - Vamos falar disso agora para depois voltarmos na parte de estatística

# %%
# Antes de falarmos de estatística, vamos precisar selecionar apenas as colunas que vamos trabalhar para evitar esse erro
# com essa funcao esperamos calcular a media das colunas, porem nem todas elas sao numericas, portanto haverá erro na tentativa de calcular media das colunas nao numericas
base.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jharbes\Documents\GitHub\hashtagDatascience\004-pandas_e_numpy\15-introducao_pandas-info_estatisticas_e_filtros_na_base\introducao_ao_pandas.ipynb Célula 41 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/jharbes/Documents/GitHub/hashtagDatascience/004-pandas_e_numpy/15-introducao_pandas-info_estatisticas_e_filtros_na_base/introducao_ao_pandas.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> # Antes de falarmos de estatística, vamos precisar selecionar apenas as colunas que vamos trabalhar para evitar esse erro
#       <a href='vscode-notebook-cell:/c%3A/Users/jharbes/Documents/GitHub/hashtagDatascience/004-pandas_e_numpy/15-introducao_pandas-info_estatisticas_e_filtros_na_base/introducao_ao_pandas.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> # com essa funcao esperamos calcular a media das colunas, porem nem todas elas sao numericas, portanto haverá erro na tentativa de calcular media das colunas nao numericas
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jharbes/Documents/GitHub/hashtagDatascience/004-pandas_e_numpy/15-introducao_pandas-info_estatisticas_e_filtros_na_base/introducao_ao_pandas.ipynb#X55sZmlsZQ%3D%3D?line=2'>3</a> base.mean()
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\frame.py:10524, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10520     df = df.T
#   10522 # After possibly _get_data and transposing, we are now in the
#   10523 #  simple case where we can use BlockManager.reduce
# > 10524 res = df._mgr.reduce(blk_func)
#   10525 out = df._constructor(res).iloc[0]
#   10526 if out_dtype is not None:
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\internals\managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\internals\blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\frame.py:10487, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10485     return values._reduce(name, skipna=skipna, **kwds)
#   10486 else:
# > 10487     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Python3.10.11\lib\site-packages\pandas\core\nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File c:\Python3.10.11\lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Buscando por uma coluna:** <br>

# %%
# Podemos usar o nome da coluna entre aspas
# ou usar tambem o nome da base.nomedacoluna conforme abaixo
print(base["Title"],end='\n\n')

print(base.Title)
# Out:
# 0       Tiger King: Murder, Mayhem …
# 1                              Ozark
# 2                       All American
# 3                       Blood Father
# 4                       The Platform
#                     ...
# 7095             Worst Roommate Ever
# 7096               Vikings: Valhalla
# 7097                         Shooter
# 7098                         Shrek 2
# 7099                           Shrek
# Name: Title, Length: 7100, dtype: object
#
# 0       Tiger King: Murder, Mayhem …
# 1                              Ozark
# 2                       All American
# 3                       Blood Father
# 4                       The Platform
#                     ...
# 7095             Worst Roommate Ever
# 7096               Vikings: Valhalla
# 7097                         Shooter
# 7098                         Shrek 2
# 7099                           Shrek
# Name: Title, Length: 7100, dtype: object

# %%
# Ou usar o ponto (só funciona se o nome da coluna nao tiver caracteres espaço no nome)
base.Title
# Out:
# 0       Tiger King: Murder, Mayhem …
# 1                              Ozark
# 2                       All American
# 3                       Blood Father
# 4                       The Platform
#                     ...
# 7095             Worst Roommate Ever
# 7096               Vikings: Valhalla
# 7097                         Shooter
# 7098                         Shrek 2
# 7099                           Shrek
# Name: Title, Length: 7100, dtype: object

# %%
base['Year to Date Rank']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#         ..
# 7095     5
# 7096     7
# 7097     8
# 7098     9
# 7099    10
# Name: Year to Date Rank, Length: 7100, dtype: object

# %% [markdown]
# **O value_counts() permite contar os valores de uma coluna:** <br>
# base["Coluna"]<font color="blue">**.value_counts()**</font>

# %%
base["Title"].value_counts()
# Out:
# Title
# Cocomelon                       428
# Ozark                            85
# Cobra Kai                        81
# Manifest                         80
# The Queenâs Gambit             73
#                                ...
# The Office                        1
# Animals on the Loose: A You…      1
# Dark                              1
# The Secret Life of Pets 2         1
# Step Up Revolution                1
# Name: count, Length: 645, dtype: int64

# %% [markdown]
# **Para selecionar mais de 1 coluna, basta passar uma lista com os valores que queremos buscar:** <br>

# %%
# Para selecionar mais de uma coluna incluiremos elas em uma lista
lista_colunas = ["Rank","Days In Top 10","Viewership Score"]
print(base[lista_colunas])
# Out:
#       Rank  Days In Top 10  Viewership Score
# 0        1               9                90
# 1        2               5                45
# 2        3               9                76
# 3        4               5                30
# 4        5               9                55
# ...    ...             ...               ...
# 7095     6              10                81
# 7096     7              14               100
# 7097     8               3                 7
# 7098     9              10                33
# 7099    10               7                12
#
# [7100 rows x 3 columns]

# %% [markdown]
# ### Voltando para as informações estatísticas

# %% [markdown]
# Obs: Colunas que estejam do tipo objeto não vão ter informações estatísticas!

# %%
# Selecionando a base que vamos mostrar informações estatísticas (apenas bases numéricas para que possam haver calculos)
base_estatistica = base[["Rank","Days In Top 10","Viewership Score"]]

# %%
print(base_estatistica.head())
# Out:
#    Rank  Days In Top 10  Viewership Score
# 0     1               9                90
# 1     2               5                45
# 2     3               9                76
# 3     4               5                30
# 4     5               9                55

# %%
print(base_estatistica.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              7100 non-null   int64
#  1   Days In Top 10    7100 non-null   int64
#  2   Viewership Score  7100 non-null   int64
# dtypes: int64(3)
# memory usage: 166.5 KB
# None

# %%
# Mostrando a média
base_estatistica.mean()
# Out:
# Rank                  5.500000
# Days In Top 10       24.123662
# Viewership Score    122.790141
# dtype: float64

# %%
# Mostrando a contagem de registros
base_estatistica.count()
# Out:
# Rank                7100
# Days In Top 10      7100
# Viewership Score    7100
# dtype: int64

# %%
# Mediana
base_estatistica.median()
# Out:
# Rank                 5.5
# Days In Top 10       7.0
# Viewership Score    50.0
# dtype: float64

# %%
# Desvio Padrão
base_estatistica.std()
# Out:
# Rank                  2.872484
# Days In Top 10       58.473789
# Viewership Score    213.861642
# dtype: float64

# %% [markdown]
# **Também podemos usar o <font color="blue">**describe**</font> para trazer todo o resumo estatístico:** <br>
# base<font color="blue">**.describe()**</font>

# %%
print(base_estatistica.describe())
# Out:
#               Rank  Days In Top 10  Viewership Score
# count  7100.000000     7100.000000       7100.000000
# mean      5.500000       24.123662        122.790141
# std       2.872484       58.473789        213.861642
# min       1.000000        1.000000          1.000000
# 25%       3.000000        3.000000         19.000000
# 50%       5.500000        7.000000         50.000000
# 75%       8.000000       18.000000        128.000000
# max      10.000000      428.000000       1474.000000

# %% [markdown]
# ### Também conseguimos fazer filtros na base

# %%
display(base)
# Out:
#            As of  Rank Year to Date Rank Last Week Rank
# 0     2020-04-01     1                 1              1  \
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes  \
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# 3                     Blood Father    Movie               NaN
# 4                     The Platform    Movie               Yes
# ...                            ...      ...               ...
# 7095           Worst Roommate Ever  TV Show               Yes
# 7096             Vikings: Valhalla  TV Show               Yes
# 7097                       Shooter    Movie               NaN
# 7098                       Shrek 2    Movie               NaN
# 7099                         Shrek    Movie               NaN
#
#      Netflix Release Date  Days In Top 10  Viewership Score
# 0            Mar 20, 2020               9                90
# 1            Jul 21, 2017               5                45
# 2            Mar 28, 2019               9                76
# 3            Mar 26, 2020               5                30
# 4            Mar 20, 2020               9                55
# ...                   ...             ...               ...
# 7095          Mar 1, 2022              10                81
# 7096         Feb 25, 2022              14               100
# 7097          Aug 1, 2014               3                 7
# 7098          Mar 1, 2022              10                33
# 7099          May 1, 2018               7                12
#
# [7100 rows x 10 columns]

# %%
# Filtrando apenas programas que ficaram mais de 100 dias no Top 10
base[base["Days In Top 10"] > 100]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank      Title     Type
# 2896  2021-01-15     7                 7             10  Cocomelon  TV Show  \
# 2909  2021-01-16    10                 7              9  Cocomelon  TV Show
# 2919  2021-01-17    10                10              9  Cocomelon  TV Show
# 3019  2021-01-27    10                 -              -  Cocomelon  TV Show
# 3029  2021-01-28    10                10              -  Cocomelon  TV Show
# ...          ...   ...               ...            ...        ...      ...
# 6674  2022-01-28     5                 6              -  Cocomelon  TV Show
# 6687  2022-01-29     8                 5              8  Cocomelon  TV Show
# 6718  2022-02-01     9                 -              7  Cocomelon  TV Show
# 6959  2022-02-25    10                 -              -  Cocomelon  TV Show
# 6998  2022-03-01     9                 -              -  Cocomelon  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 2896               NaN          Jun 1, 2020             101               291
# 2909               NaN          Jun 1, 2020             102               292
# 2919               NaN          Jun 1, 2020             103               293
# 3019               NaN          Jun 1, 2020             104               294
# 3029               NaN          Jun 1, 2020             105               295
# ...                ...                  ...             ...               ...
# 6674               NaN          Jun 1, 2020             424              1466
# 6687               NaN          Jun 1, 2020             425              1469
# 6718               NaN          Jun 1, 2020             426              1471
# 6959               NaN          Jun 1, 2020             427              1472
# 6998               NaN          Jun 1, 2020             428              1474
#
# [328 rows x 10 columns]

# %%
base[base.Title == "Ozark"]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  Title     Type
# 1     2020-04-01     2                 2              -  Ozark  TV Show  \
# 11    2020-04-02     2                 2              -  Ozark  TV Show
# 21    2020-04-03     2                 2              -  Ozark  TV Show
# 31    2020-04-04     2                 2              2  Ozark  TV Show
# 41    2020-04-05     2                 2              2  Ozark  TV Show
# ...          ...   ...               ...            ...    ...      ...
# 6954  2022-02-25     5                 5              5  Ozark  TV Show
# 6967  2022-02-26     8                 5              8  Ozark  TV Show
# 6979  2022-02-27    10                 8              7  Ozark  TV Show
# 6986  2022-02-28     7                10              7  Ozark  TV Show
# 6996  2022-03-01     7                 7              8  Ozark  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 1                  Yes         Jul 21, 2017               5                45
# 11                 Yes         Jul 21, 2017               6                54
# 21                 Yes         Jul 21, 2017               7                63
# 31                 Yes         Jul 21, 2017               8                72
# 41                 Yes         Jul 21, 2017               9                81
# ...                ...                  ...             ...               ...
# 6954               Yes         Jul 21, 2017              85               524
# 6967               Yes         Jul 21, 2017              86               527
# 6979               Yes         Jul 21, 2017              87               528
# 6986               Yes         Jul 21, 2017              88               532
# 6996               Yes         Jul 21, 2017              89               536
#
# [85 rows x 10 columns]

# %%
# Podemos fazer filtros usando E / OU
base[(base["Days In Top 10"] > 100) & (base["Title"] != "Cocomelon")]
# Out:
# Empty DataFrame
# Columns: [As of, Rank, Year to Date Rank, Last Week Rank, Title, Type, Netflix Exclusive, Netflix Release Date, Days In Top 10, Viewership Score]
# Index: []

# %%
base[(base["Title"] == "Squid Game") | (base["Title"] == "Ozark")]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  Title     Type
# 1     2020-04-01     2                 2              -  Ozark  TV Show  \
# 11    2020-04-02     2                 2              -  Ozark  TV Show
# 21    2020-04-03     2                 2              -  Ozark  TV Show
# 31    2020-04-04     2                 2              2  Ozark  TV Show
# 41    2020-04-05     2                 2              2  Ozark  TV Show
# ...          ...   ...               ...            ...    ...      ...
# 6954  2022-02-25     5                 5              5  Ozark  TV Show
# 6967  2022-02-26     8                 5              8  Ozark  TV Show
# 6979  2022-02-27    10                 8              7  Ozark  TV Show
# 6986  2022-02-28     7                10              7  Ozark  TV Show
# 6996  2022-03-01     7                 7              8  Ozark  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 1                  Yes         Jul 21, 2017               5                45
# 11                 Yes         Jul 21, 2017               6                54
# 21                 Yes         Jul 21, 2017               7                63
# 31                 Yes         Jul 21, 2017               8                72
# 41                 Yes         Jul 21, 2017               9                81
# ...                ...                  ...             ...               ...
# 6954               Yes         Jul 21, 2017              85               524
# 6967               Yes         Jul 21, 2017              86               527
# 6979               Yes         Jul 21, 2017              87               528
# 6986               Yes         Jul 21, 2017              88               532
# 6996               Yes         Jul 21, 2017              89               536
#
# [151 rows x 10 columns]

# %%
base[base["Title"] == "Squid Game"]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank       Title     Type
# 5367  2021-09-19     8                 -              -  Squid Game  TV Show  \
# 5371  2021-09-20     2                 8              -  Squid Game  TV Show
# 5381  2021-09-21     2                 2              -  Squid Game  TV Show
# 5390  2021-09-22     1                 2              -  Squid Game  TV Show
# 5400  2021-09-23     1                 1              -  Squid Game  TV Show
# ...          ...   ...               ...            ...         ...      ...
# 5999  2021-11-21    10                 -              8  Squid Game  TV Show
# 6009  2021-11-22    10                10              8  Squid Game  TV Show
# 6049  2021-11-26    10                 -             10  Squid Game  TV Show
# 6059  2021-11-27    10                10              -  Squid Game  TV Show
# 6068  2021-11-28     9                10             10  Squid Game  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 5367               Yes         Sep 17, 2021               1                 3
# 5371               Yes         Sep 17, 2021               2                12
# 5381               Yes         Sep 17, 2021               3                21
# 5390               Yes         Sep 17, 2021               4                31
# 5400               Yes         Sep 17, 2021               5                41
# ...                ...                  ...             ...               ...
# 5999               Yes         Sep 17, 2021              62               490
# 6009               Yes         Sep 17, 2021              63               491
# 6049               Yes         Sep 17, 2021              64               492
# 6059               Yes         Sep 17, 2021              65               493
# 6068               Yes         Sep 17, 2021              66               495
#
# [66 rows x 10 columns]

# %% [markdown]
# #### Uma forma muito útil de fazer seleção de dados é usando o <font color="blue">.loc()</font> ou o <font color="blue">.iloc()</font>

# %%
# O .loc() permite fazer a busca da mesma forma acima
base.loc[base["Days In Top 10"] > 100]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank      Title     Type
# 2896  2021-01-15     7                 7             10  Cocomelon  TV Show  \
# 2909  2021-01-16    10                 7              9  Cocomelon  TV Show
# 2919  2021-01-17    10                10              9  Cocomelon  TV Show
# 3019  2021-01-27    10                 -              -  Cocomelon  TV Show
# 3029  2021-01-28    10                10              -  Cocomelon  TV Show
# ...          ...   ...               ...            ...        ...      ...
# 6674  2022-01-28     5                 6              -  Cocomelon  TV Show
# 6687  2022-01-29     8                 5              8  Cocomelon  TV Show
# 6718  2022-02-01     9                 -              7  Cocomelon  TV Show
# 6959  2022-02-25    10                 -              -  Cocomelon  TV Show
# 6998  2022-03-01     9                 -              -  Cocomelon  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 2896               NaN          Jun 1, 2020             101               291
# 2909               NaN          Jun 1, 2020             102               292
# 2919               NaN          Jun 1, 2020             103               293
# 3019               NaN          Jun 1, 2020             104               294
# 3029               NaN          Jun 1, 2020             105               295
# ...                ...                  ...             ...               ...
# 6674               NaN          Jun 1, 2020             424              1466
# 6687               NaN          Jun 1, 2020             425              1469
# 6718               NaN          Jun 1, 2020             426              1471
# 6959               NaN          Jun 1, 2020             427              1472
# 6998               NaN          Jun 1, 2020             428              1474
#
# [328 rows x 10 columns]

# %%
# Ele também permite usar argumentos lógicos
base.loc[(base["Title"] == "Squid Game") | (base["Title"] == "Ozark")]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  Title     Type
# 1     2020-04-01     2                 2              -  Ozark  TV Show  \
# 11    2020-04-02     2                 2              -  Ozark  TV Show
# 21    2020-04-03     2                 2              -  Ozark  TV Show
# 31    2020-04-04     2                 2              2  Ozark  TV Show
# 41    2020-04-05     2                 2              2  Ozark  TV Show
# ...          ...   ...               ...            ...    ...      ...
# 6954  2022-02-25     5                 5              5  Ozark  TV Show
# 6967  2022-02-26     8                 5              8  Ozark  TV Show
# 6979  2022-02-27    10                 8              7  Ozark  TV Show
# 6986  2022-02-28     7                10              7  Ozark  TV Show
# 6996  2022-03-01     7                 7              8  Ozark  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 1                  Yes         Jul 21, 2017               5                45
# 11                 Yes         Jul 21, 2017               6                54
# 21                 Yes         Jul 21, 2017               7                63
# 31                 Yes         Jul 21, 2017               8                72
# 41                 Yes         Jul 21, 2017               9                81
# ...                ...                  ...             ...               ...
# 6954               Yes         Jul 21, 2017              85               524
# 6967               Yes         Jul 21, 2017              86               527
# 6979               Yes         Jul 21, 2017              87               528
# 6986               Yes         Jul 21, 2017              88               532
# 6996               Yes         Jul 21, 2017              89               536
#
# [151 rows x 10 columns]

# %%
# Ele permite filtrar colunas de forma muito prática
base.loc[(base["Title"] == "Squid Game") | (base["Title"] == "Ozark"),["As of","Title",'Type']]
# Out:
#            As of  Title     Type
# 1     2020-04-01  Ozark  TV Show
# 11    2020-04-02  Ozark  TV Show
# 21    2020-04-03  Ozark  TV Show
# 31    2020-04-04  Ozark  TV Show
# 41    2020-04-05  Ozark  TV Show
# ...          ...    ...      ...
# 6954  2022-02-25  Ozark  TV Show
# 6967  2022-02-26  Ozark  TV Show
# 6979  2022-02-27  Ozark  TV Show
# 6986  2022-02-28  Ozark  TV Show
# 6996  2022-03-01  Ozark  TV Show
#
# [151 rows x 3 columns]

# %% [markdown]
# **Já o <font color="blue">.iloc() </font> vai usar o índice para filtrar**

# %%
# Buscando as linhas de 30 (inclusive) a 40 (exclusive)
base.iloc[30:40]
# Out:
#          As of  Rank Year to Date Rank Last Week Rank
# 30  2020-04-04     1                 1              1  \
# 31  2020-04-04     2                 2              2
# 32  2020-04-04     3                 -              -
# 33  2020-04-04     4                 3              3
# 34  2020-04-04     5                 -              -
# 35  2020-04-04     6                 4              -
# 36  2020-04-04     7                 6              -
# 37  2020-04-04     8                 5              -
# 38  2020-04-04     9                 7              -
# 39  2020-04-04    10                 8              -
#
#                            Title     Type Netflix Exclusive
# 30  Tiger King: Murder, Mayhem …  TV Show               Yes  \
# 31                         Ozark  TV Show               Yes
# 32                   Money Heist  TV Show               Yes
# 33                  All American  TV Show               NaN
# 34               Coffee & Kareem    Movie               Yes
# 35     How to Fix a Drug Scandal  TV Show               Yes
# 36                  The Roommate    Movie               NaN
# 37                    Nailed It!  TV Show               Yes
# 38                    Unorthodox  TV Show               Yes
# 39              The Players Club    Movie               NaN
#
#    Netflix Release Date  Days In Top 10  Viewership Score
# 30         Mar 20, 2020              12               120
# 31         Jul 21, 2017               8                72
# 32         Dec 20, 2017               1                 8
# 33         Mar 28, 2019              12                99
# 34          Apr 3, 2020               1                 6
# 35          Apr 1, 2020               3                18
# 36          Apr 1, 2020               3                13
# 37          Mar 9, 2018               3                16
# 38         Mar 26, 2020               5                14
# 39          Apr 1, 2020               2                 4

# %%
# Também posso usar para buscar apenas colunas específicas
base.iloc[30:40,[0,4,5]]
# Out:
#          As of                         Title     Type
# 30  2020-04-04  Tiger King: Murder, Mayhem …  TV Show
# 31  2020-04-04                         Ozark  TV Show
# 32  2020-04-04                   Money Heist  TV Show
# 33  2020-04-04                  All American  TV Show
# 34  2020-04-04               Coffee & Kareem    Movie
# 35  2020-04-04     How to Fix a Drug Scandal  TV Show
# 36  2020-04-04                  The Roommate    Movie
# 37  2020-04-04                    Nailed It!  TV Show
# 38  2020-04-04                    Unorthodox  TV Show
# 39  2020-04-04              The Players Club    Movie

# %% [markdown]
# ### Por fim, conseguimos fazer gráficos com o Pandas de forma bem simples
#
# - https://pandas.pydata.org/docs/user_guide/visualization.html

# %%
import matplotlib.pyplot as plt

# %%
# É possível fazer um histograma simples
base["Days In Top 10"].plot.hist();

# %%
# Gráficos de barras
base.Title.value_counts().head(15).plot.bar();
# Out:
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128 (\x80) missing from current font.
#   func(*args, **kwargs)
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:89: UserWarning: Glyph 153 (\x99) missing from current font.
#   func(*args, **kwargs)
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
base.Title.value_counts().head(15).plot.bar();
# Out:
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128 (\x80) missing from current font.
#   func(*args, **kwargs)
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:89: UserWarning: Glyph 153 (\x99) missing from current font.
#   func(*args, **kwargs)
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\jharbes\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# E até gráficos mais complexos como o de densidade
base["Viewership Score"].plot.kde();
